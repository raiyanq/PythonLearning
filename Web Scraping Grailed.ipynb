# %%
#import appropriate libraries for web scraping and data science
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
my_url = 'https://www.harryrosen.com/en/clothing/c/new-clothing?pageSize=96'

# %%
#Open a connection to retreive the page and close connection after
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

# %%
filename = "products.csv"
f = open(filename, "w")

headers = "brand, price"

# %%
page_soup = soup(page_html, "html.parser")
containers = page_soup.findAll("div",{"class":"hr-product-lister-grid-item-content-wp"})

for container in containers:
    brand = container.h3.text
    product_name = container.h4.text
    price = container.findAll("div", {"class":"hr-product-price"})[0].text
    print(brand + product_name + price)
    f.write(brand + ',' + product_name.replace(",", "|") + ',' + price.replace(",", "") + "\n")
# Out:
# DieselCotton Sport Shirt
# 			$178.00
# Thom BrowneCotton Shirt
# 			$590.00
# Ermenegildo ZegnaMilano Suit
# 			$3,495.00
# EtonSlim Fit Dress Shirt
# 			$290.00
# Paul & SharkPrinted Cotton & Wool Blend Shirt
# 			$295.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,698.00
# EtonSlim Fit Dress Shirt
# 			$290.00
# Ermenegildo ZegnaMilano Suit
# 			$3,295.00
# EtonContemporary Fit Dress Shirt
# 			$280.00
# EtonSlim Fit Dress Shirt
# 			$280.00
# Ermenegildo ZegnaTorino Multi-Season Suit
# 			$3,295.00
# MonclerRodez Down Jacket
# 			$1,430.00
# Giorgio ArmaniV-Neck T-Shirt
# 			$375.00
# Ermenegildo ZegnaCouture Suit
# 			$6,185.00
# Ermenegildo ZegnaMilano Suit
# 			$3,295.00
# Brunello CucinelliWaterproof Down Vest
# 			$1,775.00
# Ermenegildo ZegnaLong-Sleeve Cotton Polo
# 			$475.00
# Brunello CucinelliLong-Sleeve Cashmere Blend Polo
# 			$1,175.00
# Brunello CucinelliLong-Sleeve Cashmere Blend Polo
# 			$1,175.00
# Brunello CucinelliWaterproof Down Vest
# 			$3,025.00
# Ermenegildo ZegnaCotton Blend Zip-Up Sweater
# 			$875.00
# Brunello CucinelliWool Blend Sweater
# 			$1,145.00
# Ermenegildo ZegnaCotton Blend Zip-Up Sweater
# 			$875.00
# Paul & SharkCrew Neck Wool Sweater
# 			$395.00
# Paul & SharkCashmere & Wool Blend Sweater
# 			$495.00
# Giorgio ArmaniV-Neck T-Shirt
# 			$375.00
# Brunello CucinelliWaterproof Down Coat
# 			$3,895.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,698.00
# Giorgio ArmaniUpton Unstructured Sports Jacket
# 			$3,395.00
# Ermenegildo ZegnaTorino Trofeo Suit
# 			$3,495.00
# Ermenegildo ZegnaMilano Easy Sports Jacket
# 			$2,995.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,598.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,598.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,498.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,498.00
# Z ZegnaDrop 8 Turati Suit
# 			$1,598.00
# Z ZegnaDrop 8 Suit
# 			$1,498.00
# Brunello CucinelliLong-Sleeve Virgin Wool Blend Polo
# 			$1,175.00
# Brunello CucinelliWool & Cashmere Bomber Jacket
# 			$5,395.00
# Z ZegnaDrop 8 Suit
# 			$1,498.00
# Brunello CucinelliWaterproof Down Vest
# 			$1,775.00
# Loro PianaZip-Up Cashmere Sweater
# 			$3,880.00
# Loro PianaPrinted Cotton Shirt
# 			$680.00
# Ermenegildo ZegnaHalf-Zip Cashmere & Silk Sweater
# 			$2,150.00
# Loro PianaSlim Fit Pants
# 			$780.00
# Thom BrowneDown-Filled Jacket
# 			$3,650.00
# Loro PianaUnstructured Sports Jacket
# 			$4,330.00
# Loro PianaSlim Fit Jeans
# 			$780.00
# Versace CollectionSlim Fit Jeans
# 			$395.00
# Loro PianaZip-Up Cashmere & Silk Blend Sweater
# 			$2,600.00
# Loro PianaStorm System Vest
# 			$1,540.00
# Loro PianaStorm System Vest
# 			$1,540.00
# Loro PianaZip-Up Cashmere & Silk Blend Sweater
# 			$2,600.00
# Loro PianaVirgin Wool & Silk Blend Vest
# 			$2,880.00
# Brunello CucinelliSkinny Fit Jeans
# 			$675.00
# Loro PianaCashmere Sweater
# 			$2,140.00
# Loro PianaSlim Fit Jeans
# 			$780.00
# Loro PianaSlim Fit Jeans
# 			$780.00
# Versace CollectionDrawstring Joggers
# 			$395.00
# DieselKrooley JoggJeans
# 			$498.00
# Loro PianaUnstructured Sports Jacket
# 			$4,330.00
# Loro PianaCashmere Blend Coat
# 			$19,310.00
